# %%
Ques3 :
ANS: 
    # Sample monument data (can be extended for more cities)
cities = {
    "Delhi": "Red Fort",
    "Agra": "Taj Mahal",
    "Jaipur": "Jal Mahal"
}

# User input simulation
city_name = input("Enter a city name (Delhi, Agra, Jaipur): ")

# Check if city exists in the data
if city_name.upper() in cities:  # Convert to uppercase for case-insensitive matching
    monument = cities[city_name.upper()]
    print(f"The famous monument in {city_name} is {monument}.")
else:
    print(f"Sorry, information about monuments in {city_name} is not available at this time.")

# %% [raw]
# 4. Repeated Division by 3
#
# To find how many times a number can be divided by 3 before it's less than or equal to 10, we can use a loop that keeps dividing by 3 until the condition is met. Here's a Python implementation:
#
# Python
# def count_divisions_by_3(number):
#   """Counts the number of times a number can be divided by 3 before it's <= 10.
#
#   Args:
#       number: The number to check.
#
#   Returns:
#       The number of times the number can be divided by 3 before it's <= 10.
#   """
#
#   count = 0
#   while number > 10:
#     number //= 3  # Integer division for efficiency
#     count += 1
#   return count
#
# # Example usage
# number = 27
# divisions = count_divisions_by_3(number)
# print(f"{number} can be divided by 3 {divisions} times before becoming less than or equal to 10.")
#
#
#
#
# 5. while Loop in Python
#
# The while loop is a fundamental control flow statement in Python that executes a block of code repeatedly as long as a given condition remains True. It's useful for iterating a specific number of times or until a certain condition is met.
#
# Syntax:
#
# Python
# while condition:
#   # Code to be executed repeatedly
# Use code with caution.
# content_copy
# Example:
#
# Python
# count = 1
# while count <= 5:
#   print(count)
#   count += 1
# Use code with caution.
# content_copy
# This code prints numbers from 1 to 5 (inclusive).
#
# When to Use while Loop:
#
# When you don't know the exact number of iterations beforehand (e.g., user input).
# When the loop condition depends on a changing variable.
#
#
# 6. Nested while Loops for Patterns
#
# Nested loops allow you to create complex patterns by iterating within another loop. Here's an example of three patterns:
#
# Pattern 1: Right-angled Triangle
#
# Python
# rows = 5
# for i in range(rows):
#   for j in range(i + 1):
#     print("*", end="")
#   print()
# Use code with caution.
# content_copy
# Pattern 2: Number Pyramid
#
# Python
# rows = 5
# for i in range(rows):
#   for j in range(rows - i - 1):
#     print(" ", end="")
#   for j in range(2 * i + 1):
#     print(i + 1, end="")
#   print()
#
# Pattern 3: Diamond
#
# Python
# rows = 5
# for i in range(rows):
#   for j in range(rows - i - 1):
#     print(" ", end="")
#   for j in range(2 * i + 1):
#     print("*", end="")
#   print()
#
# for i in range(rows - 2, -1, -1):
#   for j in range(rows - i - 1):
#     print(" ", end="")
#   for j in range(2 * i + 1):
#     print("*", end="")
#   print()
#
#
# 7. and 8. Reversed while Loop (10 to 1)
#
# To reverse a while loop and display numbers from 10 to 1, we can use a decrementing counter instead of an incrementing one. Here's how:
#
# Python
# number = 10
# while number > 0:
#   print(number)
#   number -= 1
